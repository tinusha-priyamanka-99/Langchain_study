# %%
import seaborn as sns
import pandas as pd

# %%
data_dict = {'total_bill': [16.99,10.34,21.01,23.68,24.59], 
             'tip': [1.01,1.66,3.5,3.31,3.61],
             'Sex': ['Female','Male','Male','Male','Female'],
             'Smoker':['No','No','No','No','No'],
             'day':['Sun','Sun','Sun','Sun','Sun'],
             'time': ['Dinner','Dinner','Dinner','Dinner','Dinner'],
             'size': [2,3,3,2,4]}
df = pd.DataFrame(data_dict)

# %%
df.dtypes
# Out:
# total_bill    float64
# tip           float64
# Sex            object
# Smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
selected_columns = [ 'total_bill', 'tip','size']
correlation_matrix = df[selected_columns].corr()
correlation_matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.791002  0.166315
# tip           0.791002  1.000000  0.475753
# size          0.166315  0.475753  1.000000

# %%
sns.heatmap(correlation_matrix)
# Out:
# <Axes: >

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='tip')

# %%
df['Smoker'].value_counts()
# Out:
# Smoker
# No    5
# Name: count, dtype: int64

# %%
sns.distplot(df['tip'])
# Out:
# C:\Users\tinus\AppData\Local\Temp\ipykernel_21480\4235560333.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(df['tip'],kde=False,bins=5)
# Out:
# C:\Users\tinus\AppData\Local\Temp\ipykernel_21480\3610155024.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'],kde=False,bins=5)
# <Axes: xlabel='tip'>

# %%
sns.countplot('Sex')
# Out:
# <Axes: xlabel='count'>
